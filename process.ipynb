# %%
input_path = "data/raw/daivietsuky-text.pdf"
output_path = "data/raw/daivietsuky-text.txt"

# %%
from scripts.extract_txt_from_pdf import pdf_to_txt
pdf_to_txt(input_path, output_path)
# Out:
# Đang xử lý 739 trang...
# ✅ Chuyển đổi thành công! File lưu tại: data/raw/daivietsuky-text.txt
# ...

# %%
# First, let's check what functions are available in the alignment module
import scripts.alignment
print("Available functions in scripts.alignment:")
print([func for func in dir(scripts.alignment) if not func.startswith('_')])

# If you need to see the source code to understand the correct function name:
import inspect
try:
    print("\nSource code preview:")
    print(inspect.getsource(scripts.alignment))
except:
    print("Could not retrieve source code")
# Out:
# Available functions in scripts.alignment:
# ['SequenceMatcher', 'align_text_with_bbox', 'find_best_match', 'json', 'load_cache_file', 'merge_bbox_group', 'merge_multiline_text', 'normalize_text', 're', 'save_aligned_data']
#
# Source code preview:
# import json
#
# def load_cache(cache_path):
#     """
#     Đọc file cache
#
#     Returns:
#         dict: {filename: [{transcription, points, difficult}]}
#     """
#     cache_data = {}
#     with open(cache_path, 'r', encoding='utf-8') as f:
#         for line in f:
#             line = line.strip()
#             if not line:
#                 continue
#
#             parts = line.split('\t', 1)
#             if len(parts) == 2:
#                 filename = parts[0]
#                 ocr_data = json.loads(parts[1])
#                 cache_data[filename] = ocr_data
#
#     return cache_data
#
#
# def load_ground_truth_txt(txt_path):
#     """
#     Đọc file TXT ground truth
#
#     Returns:
#         list: Danh sách các dòng text
# ...
